# %%
pip install lightgbm==4.1.0
# Out:
# Collecting lightgbm==4.1.0
#   Using cached lightgbm-4.1.0-py3-none-macosx_10_15_x86_64.macosx_11_6_x86_64.macosx_12_5_x86_64.whl (1.7 MB)
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from lightgbm==4.1.0) (1.7.1)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from lightgbm==4.1.0) (1.21.1)
# Installing collected packages: lightgbm
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 3.2.1
#     Uninstalling lightgbm-3.2.1:
#       Successfully uninstalled lightgbm-3.2.1
# Successfully installed lightgbm-4.1.0
# WARNING: You are using pip version 22.0.3; however, version 23.2.1 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyscipopt import Model, Eventhdlr, SCIP_EVENTTYPE,SCIP_HEURTIMING
import pyscipopt
import sys , os
import time
import random
import pandas as pd
import numpy as np
import joblib
import lightgbm as lgb

# %%
print(lgb.__version__)
# Out:
# 4.1.0

# %%
class FixedVarsAtNode(Eventhdlr):
    """PySCIPOpt Event handler to write fixed vars of each node to a text file."""

    def __init__(self):

        self.count=0
        self.count_limit=-1

        self.MLmodel_path = "model/lgb_model_test1.pkl"
        
        self.MLmodel = joblib.load(self.MLmodel_path)
        print(type(self.MLmodel))

        self.nextnode = False
        

    def eventexec(self, event):
        if self.count>self.count_limit:
            
            self.df_test_info = pd.DataFrame()
            self.transvars = self.model.getVars(transformed=True)
            self.depth = self.model.getDepth()
            for var in self.transvars:
                Glb = var.getUbGlobal()#获取变量的全局上界
                Gub = var.getLbGlobal()#获取变量的全局下界
                lb = var.getLbLocal()  # 获取变量的局部下界
                ub = var.getUbLocal()  # 获取变量的局部上界
                var_type = 0 if var.vtype()=='BINARY' else 1
                    
                test_info_add_df ={'Depth':self.depth,'Type': int(var_type), 'LowerBound': lb, 'UpperBound': ub, 'GLB':Glb, 'GUB':Gub}
                #append to df_var_info
                self.df_test_info = self.df_test_info.append(test_info_add_df, ignore_index=True)

            y_pred_prob = self.MLmodel.predict(self.df_test_info,num_iteration=30)
            
            y_pred = [1 if p>0.5 else 0 for p in y_pred_prob]
            y_pred = [int(x) for x in y_pred]
            
            # 检查 y_pred 中是否有至少一个1
            if 1 in y_pred:
                self.nextnode = True
                self.model.setIntParam("heuristics/rins/freq",1)
            else:
                self.nextnode = False
                self.model.setIntParam("heuristics/rins/freq",100)  

            self.count += 1
        else:
            pass  

    def eventinit(self):
        self.model.catchEvent(SCIP_EVENTTYPE.NODESOLVED, self)

    def eventexit(self):
        self.model.dropEvent(SCIP_EVENTTYPE.NODESOLVED, self)

# %%
if __name__ == "__main__":
    
    test = pyscipopt.scip.Model()
    test.readProblem("/Users/oukeikou/Desktop/sunruoyao/DATA/easy-sample/markshare_4_0.mps")
    print("read done")

    # Create and add event handler with the specified output file
    eventhdlr = FixedVarsAtNode()
    test.includeEventhdlr(eventhdlr, "FixedVarsAtNode", "Python event handler to write fixed variables after each solved node")

    # Optimize the problem
    start_time = time.time()
    
    test.optimize()
    # start measuring time
    end_time = time.time()

    # calculate the processing time
    elapsed_time = end_time - start_time
    
    with open("time_marks.txt", "w") as f:
            f.write(f"with ML: {elapsed_time}\n")
# Out:
# read done
# original problem has 34 variables (30 bin, 0 int, 0 impl, 4 cont) and 4 constraints
# <class 'lightgbm.basic.Booster'>
# presolving:
# (round 1, fast)       4 del vars, 0 del conss, 4 add conss, 4 chg bounds, 0 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 2, fast)       4 del vars, 4 del conss, 4 add conss, 4 chg bounds, 4 chg sides, 0 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
#    (0.0s) running MILP presolver
#    (0.0s) MILP presolver found nothing
# (round 3, exhaustive) 4 del vars, 4 del conss, 4 add conss, 4 chg bounds, 4 chg sides, 0 chg coeffs, 4 upgd conss, 0 impls, 0 clqs
#    (0.0s) probing cycle finished: starting next cycle
#    (0.0s) symmetry computation started: requiring (bin +, int -, cont +), (fixed: bin -, int +, cont -)
#    (0.0s) no symmetry present
# presolving (4 rounds: 4 fast, 2 medium, 2 exhaustive):
#  4 deleted vars, 4 deleted constraints, 4 added constraints, 4 tightened bounds, 0 added holes, 4 changed sides, 0 changed coefficients
#  0 implications, 0 cliques
# presolved problem has 30 variables (30 bin, 0 int, 0 impl, 0 cont) and 4 constraints
#       4 constraints of type <knapsack>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 0.01
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
# t 0.0s|     1 |     0 |     0 |     - | trivial|   0 |  30 |   4 |   0 |   0 |  0 |   0 |   0 |-3.084000e+03 | 3.082000e+03 |    Inf | unknown
# p 0.0s|     1 |     0 |     0 |     - |   locks|   0 |  30 |   4 |   4 |   0 |  0 |   0 |   0 |-3.084000e+03 | 5.190000e+02 |    Inf | unknown
# i 0.0s|     1 |     0 |     0 |     - |  oneopt|   0 |  30 |   4 |   4 |   0 |  0 |   0 |   0 |-3.084000e+03 | 1.330000e+02 |    Inf | unknown
#   0.0s|     1 |     0 |     5 |     - |   885k |   0 |  30 |   4 |   4 |   0 |  0 |   0 |   0 | 0.000000e+00 | 1.330000e+02 |    Inf | unknown
# r 0.0s|     1 |     0 |     5 |     - |rounding|   0 |  30 |   4 |   4 |   0 |  0 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |     9 |     - |   925k |   0 |  30 |   4 |   6 |   2 |  1 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |    11 |     - |   985k |   0 |  30 |   4 |   7 |   3 |  2 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |    14 |     - |  1002k |   0 |  30 |   4 |   8 |   4 |  3 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |    15 |     - |  1099k |   0 |  30 |   4 |  10 |   6 |  4 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |    16 |     - |  1109k |   0 |  30 |   4 |  11 |   7 |  5 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |    18 |     - |  1161k |   0 |  30 |   4 |  12 |   8 |  6 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |    19 |     - |  1162k |   0 |  30 |   4 |  13 |   9 |  7 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |    24 |     - |  1331k |   0 |  30 |   4 |  14 |  10 |  8 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |    27 |     - |  1333k |   0 |  30 |   4 |  15 |  11 |  9 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#   0.0s|     1 |     0 |    30 |     - |  1399k |   0 |  30 |   4 |  16 |  12 | 10 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#   0.0s|     1 |     0 |    32 |     - |  1431k |   0 |  30 |   4 |  17 |  13 | 11 |   0 |   0 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
#   0.1s|     1 |     2 |    69 |     - |  1439k |   0 |  30 |   4 |  17 |  13 | 11 |   0 |   8 | 0.000000e+00 | 6.500000e+01 |    Inf | unknown
# r 0.9s|    23 |    16 |   136 |   4.7 |rounding|  15 |  30 |   4 |  10 |  19 |  0 |   0 |  21 | 0.000000e+00 | 6.100000e+01 |    Inf | unknown
# r 1.3s|    33 |    23 |   176 |   4.5 |simplero|  16 |  30 |   4 |  10 |  21 |  0 |   0 |  34 | 0.000000e+00 | 4.100000e+01 |    Inf | unknown
# r 2.0s|    54 |    36 |   264 |   4.4 |rounding|  19 |  30 |   4 |  10 |  23 |  0 |   0 |  61 | 0.000000e+00 | 3.500000e+01 |    Inf | unknown
#   3.8s|   100 |    76 |   463 |   4.4 |  2206k |  19 |  30 |   4 |  10 |  27 |  1 |   0 |  82 | 0.000000e+00 | 3.500000e+01 |    Inf | unknown
#   7.6s|   200 |   168 |   896 |   4.3 |  2447k |  19 |  30 |   4 |   9 |  47 |  1 |   0 |  95 | 0.000000e+00 | 3.500000e+01 |    Inf | unknown
# L 9.8s|   256 |   202 |  1025 |   3.9 |    rins|  22 |  30 |   4 |  10 |  49 |  1 |   0 | 103 | 0.000000e+00 | 2.500000e+01 |    Inf | unknown
# *10.1s|   263 |   201 |  1039 |   3.8 |    LP  |  22 |  30 |   4 |  10 |  49 |  1 |   0 | 105 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  11.6s|   300 |   238 |  1148 |   3.7 |  2864k |  22 |  30 |   4 |  10 |  55 |  1 |   0 | 105 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  15.8s|   400 |   324 |  1494 |   3.7 |  3655k |  22 |  30 |   4 |   9 |  71 |  1 |   0 | 105 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  20.6s|   500 |   408 |  1992 |   3.9 |  3716k |  22 |  30 |   4 |  10 |  91 |  1 |   1 | 105 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  25.4s|   600 |   460 |  2263 |   3.7 |  3853k |  24 |  30 |   4 |  11 | 104 |  1 |   1 | 109 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  30.6s|   700 |   518 |  2550 |   3.6 |  3900k |  25 |  30 |   4 |  10 | 112 |  1 |   1 | 112 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  35.9s|   800 |   588 |  2868 |   3.5 |  3919k |  25 |  30 |   4 |  10 | 122 |  1 |   1 | 112 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  41.4s|   900 |   654 |  3093 |   3.4 |  3951k |  25 |  30 |   4 |   9 | 126 |  1 |   1 | 112 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  47.2s|  1000 |   700 |  3346 |   3.3 |  3967k |  26 |  30 |   4 |   9 | 126 |  1 |   1 | 114 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  53.1s|  1100 |   752 |  3610 |   3.3 |  3967k |  26 |  30 |   4 |   8 | 132 |  1 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
# Restart triggered after 50 consecutive estimations that the remaining tree will be large
# (run 1, node 1117) performing user restart
#
# (restart) converted 3 cuts from the global cut pool into linear constraints
#
# presolving:
# (round 1, fast)       0 del vars, 0 del conss, 0 add conss, 0 chg bounds, 1 chg sides, 1 chg coeffs, 0 upgd conss, 0 impls, 0 clqs
# (round 2, exhaustive) 0 del vars, 0 del conss, 0 add conss, 0 chg bounds, 1 chg sides, 1 chg coeffs, 3 upgd conss, 0 impls, 0 clqs
# presolving (3 rounds: 3 fast, 2 medium, 2 exhaustive):
#  0 deleted vars, 0 deleted constraints, 0 added constraints, 0 tightened bounds, 0 added holes, 1 changed sides, 1 changed coefficients
#  0 implications, 0 cliques
# presolved problem has 30 variables (30 bin, 0 int, 0 impl, 0 cont) and 7 constraints
#       7 constraints of type <knapsack>
# transformed objective value is always integral (scale: 1)
# Presolving Time: 0.01
# transformed 100/100 original solutions to the transformed problem space
#
#  time | node  | left  |LP iter|LP it/n|mem/heur|mdpt |vars |cons |rows |cuts |sepa|confs|strbr|  dualbound   | primalbound  |  gap   | compl.
#  54.1s|     1 |     0 |  3735 |     - |  4048k |   0 |  30 |   7 |   7 |   0 |  0 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  54.1s|     1 |     0 |  3737 |     - |  4048k |   0 |  30 |   7 |   9 |   2 |  1 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  54.1s|     1 |     0 |  3739 |     - |  4048k |   0 |  30 |   7 |  11 |   4 |  2 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  54.1s|     1 |     0 |  3741 |     - |  4048k |   0 |  30 |   7 |  12 |   5 |  3 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  54.1s|     1 |     0 |  3742 |     - |  4048k |   0 |  30 |   7 |  13 |   6 |  4 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  54.1s|     1 |     0 |  3745 |     - |  4048k |   0 |  30 |   7 |  14 |   7 |  5 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  54.1s|     1 |     0 |  3748 |     - |  4048k |   0 |  30 |   7 |  15 |   8 |  6 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  54.1s|     1 |     0 |  3750 |     - |  4048k |   0 |  30 |   7 |  16 |   9 |  7 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  54.1s|     1 |     0 |  3752 |     - |  4048k |   0 |  30 |   7 |  17 |  10 |  8 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  54.1s|     1 |     0 |  3754 |     - |  4050k |   0 |  30 |   7 |  18 |  11 |  9 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  54.1s|     1 |     0 |  3756 |     - |  4051k |   0 |  30 |   7 |  19 |  12 | 10 |   1 | 116 | 0.000000e+00 | 2.200000e+01 |    Inf | unknown
#  54